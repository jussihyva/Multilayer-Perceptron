# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read dataset

dataset_training = pd.read_csv("../Data/data.csv", header=None, names=["www0","www1","www2","www3","www4","www5","www6","www7","www8","www9","www10","www11","www12","www13","www14","www15","www16","www17","www18","www19","www20","www21","www22","www23","www24","www25","www26","www27","www28","www29","www30","www31"])
print(dataset_training)
# Out:
#          www0 www1   www2   www3    www4    www5     www6     www7     www8  \
# 0      842302    M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517    M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903    M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301    M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402    M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ...  ...    ...    ...     ...     ...      ...      ...      ...
# 564    926424    M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682    M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954    M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241    M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751    B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
# ...

# %%
legends = ["M", "B"]
fig, axes = plt.subplots(16, 2, figsize=(25, 100))
axes = axes.flatten()
for i in range(0, 32):
    for legend in legends:
        legendIndexList = dataset_training.where(dataset_training["www1"] == legend).dropna().index
        axes[i].hist(dataset_training["www" + str(i)][legendIndexList],
        alpha=0.3)
    axes[i].set_title("www" + str(i), fontsize=50)
    axes[i].legend(legends, fontsize=20)
title = "Overview of dataset (Histogram)"
plt.suptitle(title, fontsize=50)
plt.show()
